# %%
#importamos el DIRECTORIO PANDAS
import pandas as pd

# %%
#importamos el DIRECTORIO Pylab
import pylab as pl

# %%
cd E:\PRO - PROGRAMACION E INGENIERIA\Curso Python en Hidrologia\Sesiones\Sesion 9\Datos Canete
# Out:
# E:\PRO - PROGRAMACION E INGENIERIA\Curso Python en Hidrologia\Sesiones\Sesion 9\Datos Canete

# %%
ls
# Out:
#  El volumen de la unidad E es INGENIERIA CIVIL
#  El n£mero de serie del volumen es: F2A6-3780
#
#  Directorio de E:\PRO - PROGRAMACION E INGENIERIA\Curso Python en Hidrologia\Sesiones\Sesion 9\Datos Canete
#
# 07/02/2015  09:59    <DIR>          .
# 07/02/2015  09:59    <DIR>          ..
# 07/02/2015  09:59           434,637 1_CARANIA.xlsx
# 07/02/2015  09:59           409,186 2_HUANGASCAR.xlsx
# 07/02/2015  09:59           389,643 3_PACARAN.xlsx
# 07/02/2015  09:59           446,477 4_TANTA.xlsx
# 07/02/2015  09:59           453,945 5_VILCA.xlsx
# 07/02/2015  09:59           422,906 6_YAUYOS.xlsx
# 07/02/2015  09:59           307,808 7_HUANTAN.xlsx
# 07/02/2015  09:59           175,847 8_TOMAS.xlsx
# 07/02/2015  09:59           262,426 9_YAURICOCHA.xlsx
# 07/02/2015  09:59            16,362 Caudales.xlsx
# 07/02/2015  09:59             4,876 Datos_Est_Canete.ipynb
# 07/02/2015  09:59            45,242 Estaciones_SinOutliers.xlsx
# ...

# %%
Estacion=pd.read_excel('Estaciones_SinOutliers.xlsx','Eneros').transpose()

# %%
Estacion
# Out:
#       Enero CARANIA  Enero TANTA  Enero VILCA  Enero YAUYOS  Enero HUANGASCAR  \
# 1963            NaN          NaN          NaN      0.000000               NaN
# 1964      50.400002    89.900002          NaN     31.299999               NaN
# 1965      76.000000    98.099998    11.200000     47.200001         45.700001
# 1966     101.800003   159.600006    14.000000     84.099998         21.200001
# 1967     174.199997   184.100006   214.800003    140.800003        144.800003
# 1968            NaN   138.600006   114.599998     69.300003          0.300000
# 1969      58.000000    94.699997    43.299999     45.200001         11.200000
# 1970     223.399994   335.899994   108.599998           NaN               NaN
# 1971     139.500000    76.800003   104.300003    119.000000         57.400002
# 1972     137.300003   131.000000    80.900002    137.899994         92.400002
# 1973     254.000000   230.399994    73.099998    167.000000         85.000000
# ...

# %%
#grafica las precipitaciones por año de cada Provincia
Estacion.plot()
pl.show()

# %%
#grafica 
Estacion.boxplot()
pl.show()

# %%
#grafico de histogramas por provincia
Estacion.hist()
pl.show()

# %%
#devuelve la media 
Estacion.mean()
# Out:
# Enero CARANIA       122.980953
# Enero TANTA         150.288889
# Enero VILCA         102.870454
# Enero YAUYOS         67.733333
# Enero HUANGASCAR     56.425000
# Enero HUANTAN       148.590476
# Enero YAURICOCHA    178.158333
# dtype: float64

# %%
#devuelve la cantidad de elementos 
Estacion.count()
# Out:
# Enero CARANIA       42
# Enero TANTA         45
# Enero VILCA         44
# Enero YAUYOS        36
# Enero HUANGASCAR    44
# Enero HUANTAN       21
# Enero YAURICOCHA    24
# dtype: int64

# %%
#devuelve tabla resumen de los dato estadisticos
Estacion.describe()
# Out:
#        Enero CARANIA  Enero TANTA  Enero VILCA  Enero YAUYOS  \
# count      42.000000    45.000000    44.000000     36.000000
# mean      122.980953   150.288889   102.870454     67.733333
# std        64.883062    69.306362    47.909190     42.796408
# min         1.300000    38.700001    11.200000      0.000000
# 25%        75.925001    95.599998    71.849998     35.150000
# 50%       117.850002   138.600006   104.250000     64.200001
# 75%       171.974998   204.399994   133.075001     91.900002
# max       254.000000   335.899994   214.800003    167.000000
#
#        Enero HUANGASCAR  Enero HUANTAN  Enero YAURICOCHA
# count         44.000000      21.000000         24.000000
# mean          56.425000     148.590476        178.158333
# std           47.058609     120.020931         69.927521
# min            0.000000       8.800000         34.900002
# 25%           21.950000      43.700001        143.474998
# 50%           42.150000     153.399994        171.400002
# ...

# %%
#devuelve la ccorrelacion entre estaciones, quiere decir la similitud expresado en porcentaje.
Estacion.corr()
# Out:
#                   Enero CARANIA  Enero TANTA  Enero VILCA  Enero YAUYOS  \
# Enero CARANIA          1.000000     0.623181     0.421246      0.816722
# Enero TANTA            0.623181     1.000000     0.241290      0.524263
# Enero VILCA            0.421246     0.241290     1.000000      0.429081
# Enero YAUYOS           0.816722     0.524263     0.429081      1.000000
# Enero HUANGASCAR       0.545741     0.214253     0.426775      0.709305
# Enero HUANTAN          0.892571     0.217643     0.616835      0.837306
# Enero YAURICOCHA       0.609595     0.487039     0.629722      0.469077
#
#                   Enero HUANGASCAR  Enero HUANTAN  Enero YAURICOCHA
# Enero CARANIA             0.545741       0.892571          0.609595
# Enero TANTA               0.214253       0.217643          0.487039
# Enero VILCA               0.426775       0.616835          0.629722
# Enero YAUYOS              0.709305       0.837306          0.469077
# ...

# %%
#devuelve la desviacion estandar
Estacion.std()
# Out:
# Enero CARANIA        64.883062
# Enero TANTA          69.306362
# Enero VILCA          47.909190
# Enero YAUYOS         42.796408
# Enero HUANGASCAR     47.058609
# Enero HUANTAN       120.020931
# Enero YAURICOCHA     69.927521
# dtype: float64

# %%
Estacion[['Enero CARANIA']].plot()
pl.show()

# %%
Estacion[['Enero HUANTAN']].plot()
pl.show()

# %%
def Hidrologia(DataHidro):
    DataHidro.plot()
    DataHidro.hist()
    pl.figure()
    DataHidro.boxplot()
    pl.show()
    return DataHidro.describe()

# %%
Hidrologia(Estacion)
# Out:
#        Enero CARANIA  Enero TANTA  Enero VILCA  Enero YAUYOS  \
# count      42.000000    45.000000    44.000000     36.000000
# mean      122.980953   150.288889   102.870454     67.733333
# std        64.883062    69.306362    47.909190     42.796408
# min         1.300000    38.700001    11.200000      0.000000
# 25%        75.925001    95.599998    71.849998     35.150000
# 50%       117.850002   138.600006   104.250000     64.200001
# 75%       171.974998   204.399994   133.075001     91.900002
# max       254.000000   335.899994   214.800003    167.000000
#
#        Enero HUANGASCAR  Enero HUANTAN  Enero YAURICOCHA
# count         44.000000      21.000000         24.000000
# mean          56.425000     148.590476        178.158333
# std           47.058609     120.020931         69.927521
# min            0.000000       8.800000         34.900002
# 25%           21.950000      43.700001        143.474998
# 50%           42.150000     153.399994        171.400002
# ...
